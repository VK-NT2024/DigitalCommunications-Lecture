# %% [markdown]
# $\DeclareMathOperator*{\argmin}{argmin}$
# $\DeclareMathOperator*{\argmax}{argmax}$
# $\DeclareMathOperator{\erf}{erf}$
# $\DeclareMathOperator{\erfc}{erfc}$
# $\DeclareMathOperator{\artanh}{artanh}$
# $\DeclareMathOperator{\expint}{expint}$
# $\DeclareMathOperator{\si}{si}$
# $\DeclareMathOperator{\sgn}{sgn}$
# $\DeclareMathOperator{\ld}{ld}$
# $\DeclareMathOperator{\rank}{rank}$
# $\DeclareMathOperator{\trace}{tr}$
# $\DeclareMathOperator{\Exp}{E}$
# $\DeclareMathOperator*{\condequal}{=}$
# $\DeclareMathOperator*{\condapprox}{\approx}$
# $\newcommand{\wt}{wt_{\rm{H}}}$
# $\newcommand{\distH}{d_{\rm{H}}}$
# $\newcommand{\prob}[1]{{\Pr \left \{ #1 \right\} }}$
# $\newcommand{\cdf}[2]{{P_{ #1 } \! \left( #2 \right) }}$
# $\newcommand{\pdf}[2]{{p_{ #1 } \! \left( #2 \right) }}$
# $\newcommand{\real}[1]{{\mathrm{Re}\left\{#1\right\}}}$
# $\newcommand{\imag}[1]{{\mathrm{Im}\left\{#1\right\}}}$
# $\newcommand{\rect}[1]{{\mathrm{rect}\left(#1\right)}}$
# $\newcommand{\tri}[1]{{\mathrm{tri}\left(#1\right)}}$
# $\newcommand{\diag}{{\mathrm{diag}}}$
# $\newcommand{\sinc}{{\mathrm{sinc}}}$
# $\newcommand{\gtx}[2]{{g_\mathrm{tx}^{#2}\!\!\left(#1\right)}}$
# $\newcommand{\gttx}[2]{{\tilde{g}_{\mathrm{tx}}^{#2}\!\left(#1\right)}}$
# $\newcommand{\grx}[2]{{g_\mathrm{rx}^{#2}\!\!\left(#1\right)}}$
# $\newcommand{\gtrx}[2]{{\tilde{g}_{\mathrm{rx}}^{#2}\!\left(#1\right)}}$
# $\newcommand{\Gtx}[1]{{G_\mathrm{tx}\!\!\left(#1\right)}}$
# $\newcommand{\Gttx}[1]{{\tilde{G}_{\mathrm{tx}}\!\left(#1\right)}}$
# $\newcommand{\Grx}[1]{{G_\mathrm{rx}\!\!\left(#1\right)}}$
# $\newcommand{\Gtrx}[1]{{\tilde{G}_{\mathrm{rx}}\!\left(#1\right)}}$
# $\newcommand{\FT}[1]{{{\cal F}\left\{#1\right\}}}$
# $\newcommand{\IFT}[1]{{{\cal F}^{-1}\left\{#1\right\}}}$
# $\newcommand{\HT}[1]{{{\cal H}\left\{#1\right\}}}$
# $\newcommand{\IHT}[1]{{{\cal H}^{-1}\left\{#1\right\}}}$
# $\newcommand{\LT}[1]{{{\cal L}\left\{#1\right\}}}$
# $\newcommand{\ILT}[1]{{{\cal L}^{-1}\left\{#1\right\}}}$
# $\newcommand{\FFT}[1]{{\mathrm{FFT}\left\{#1\right\}}}$
# $\newcommand{\IFFT}[1]{{\mathrm{IFFT}\left\{#1\right\}}}$
# $\newcommand{\ZT}[1]{{{\cal Z}\left\{#1\right\}}}$
# $\newcommand{\IZT}[1]{{{\cal Z}^{-1}\left\{#1\right\}}}$
# $\newcommand{\Hz}{{\mathrm{\:Hz}}}$
# $\newcommand{\kHz}{{\mathrm{\:kHz}}}$
# $\newcommand{\MHz}{{\mathrm{\:MHz}}}$
# $\newcommand{\GHz}{{\mathrm{\:GHz}}}$
# $\newcommand{\ms}{{\mathrm{\:ms}}}$
# $\newcommand{\mus}{{\mathrm{\:\mu s}}}$
# $\newcommand{\kmh}{{\mathrm{\:km/h}}}$
# $\newcommand{\mps}{{\mathrm{\:m/s}}}$
# $\newcommand{\dB}{{\mathrm{\:dB}}}$
# $\newcommand{\kbits}{{\mathrm{\:kbit/s}}}$
# $\newcommand{\bit}{{\mathrm{\:bit}}}$
# $\newcommand{\kBaud}{{\mathrm{\:kBaud}}}$
# $\newcommand{\with}{\quad\mathrm{with}\;\,}$
# $\newcommand{\for}{\,\mathrm{for}\;}$
# $\newcommand{\Else}{\,\mathrm{else}\;}$
# $\newcommand{\SNR}{{SNR}}$
# $\newcommand{\EbNO}{{E_{\mathrm{b}}/N_0}}$
# $\newcommand{\EbNOdB}{{10 \log_{10}(E_{\mathrm{b}}/N_0)}}$
# $\newcommand{\EsNO}{{E_{\mathrm{s}}/N_0}}$
# $\newcommand{\EsNOdB}{{10 \log_{10}(E_{\mathrm{s}}/N_0)}}$
# $\renewcommand{\vec}[1]{\mathbf{#1}}$
# $\newcommand{\av}{\vec{a}}$
# $\newcommand{\bv}{\vec{b}}$
# $\newcommand{\cv}{\vec{c}}$
# $\newcommand{\dv}{\vec{d}}$
# $\newcommand{\ev}{\vec{e}}$
# $\newcommand{\fv}{\vec{f}}$
# $\newcommand{\gv}{\vec{g}}$
# $\newcommand{\hv}{\vec{h}}$
# $\newcommand{\iv}{\vec{i}}$
# $\newcommand{\jv}{\vec{j}}$
# $\newcommand{\kv}{\vec{k}}$
# $\newcommand{\lv}{\vec{l}}$
# $\newcommand{\mv}{\vec{m}}$
# $\newcommand{\nv}{\vec{n}}$
# $\newcommand{\ov}{\vec{o}}$
# $\newcommand{\pv}{\vec{p}}$
# $\newcommand{\qv}{\vec{q}}$
# $\newcommand{\rv}{\vec{r}}$
# $\newcommand{\sv}{\vec{s}}$
# $\newcommand{\tv}{\vec{t}}$
# $\newcommand{\uv}{\vec{u}}$
# $\newcommand{\vv}{\vec{v}}$
# $\newcommand{\wv}{\vec{w}}$
# $\newcommand{\xv}{\vec{x}}$
# $\newcommand{\yv}{\vec{y}}$
# $\newcommand{\zv}{\vec{z}}$
# $\newcommand{\zerov}{\vec{0}}$
# $\newcommand{\onev}{\vec{1}}$
# $\newcommand{\alphav}{\vecs{\alpha}}$
# $\newcommand{\betav}{\vecs{\beta}}$
# $\newcommand{\varepsilonv}{\vecs{\varepsilon}}$
# $\newcommand{\gammav}{\vecs{\gamma}}$
# $\newcommand{\lambdav}{\vecs{\lambda}}$
# $\newcommand{\muv}{\vecs{\mu}}$
# $\newcommand{\omegav}{\vecs{\omega}}$
# $\newcommand{\sigmav}{\vecs{\sigma}}$
# $\newcommand{\thetav}{\vecs{\theta}}$
# $\newcommand{\psiv}{\vecs{\psi}}$
# $\newcommand{\phiv}{\vecs{\phi}}$
# $\newcommand{\zetav}{\vecs{\zeta}}$
# $\newcommand{\Am}{\vec{A}}$
# $\newcommand{\Bm}{\vec{B}}$
# $\newcommand{\Cm}{\vec{C}}$
# $\newcommand{\Dm}{\vec{D}}$
# $\newcommand{\Em}{\vec{E}}$
# $\newcommand{\Fm}{\vec{F}}$
# $\newcommand{\Gm}{\vec{G}}$
# $\newcommand{\Hm}{\vec{H}}$
# $\newcommand{\Id}{\vec{I}}$
# $\newcommand{\Jm}{\vec{J}}$
# $\newcommand{\Km}{\vec{K}}$
# $\newcommand{\Lm}{\vec{L}}$
# $\newcommand{\Mm}{\vec{M}}$
# $\newcommand{\Nm}{\vec{N}}$
# $\newcommand{\Om}{\vec{O}}$
# $\newcommand{\Pm}{\vec{P}}$
# $\newcommand{\Qm}{\vec{Q}}$
# $\newcommand{\Rm}{\vec{R}}$
# $\newcommand{\Sm}{\vec{S}}$
# $\newcommand{\Tm}{\vec{T}}$
# $\newcommand{\Um}{\vec{U}}$
# $\newcommand{\Vm}{\vec{V}}$
# $\newcommand{\Wm}{\vec{W}}$
# $\newcommand{\Xm}{\vec{X}}$
# $\newcommand{\Ym}{\vec{Y}}$
# $\newcommand{\Zm}{\vec{Z}}$
# $\newcommand{\Arv}{{\cal A}}$
# $\newcommand{\Brv}{{\cal B}}$
# $\newcommand{\Crv}{{\cal C}}$
# $\newcommand{\Drv}{{\cal D}}$
# $\newcommand{\Erv}{{\cal E}}$
# $\newcommand{\Frv}{{\cal F}}$
# $\newcommand{\Grv}{{\cal G}}$
# $\newcommand{\Hrv}{{\cal H}}$
# $\newcommand{\Irv}{{\cal I}}$
# $\newcommand{\Jrv}{{\cal J}}$
# $\newcommand{\Krv}{{\cal K}}$
# $\newcommand{\Lrv}{{\cal L}}$
# $\newcommand{\Mrv}{{\cal M}}$
# $\newcommand{\Nrv}{{\cal N}}$
# $\newcommand{\Orv}{{\cal O}}$
# $\newcommand{\Prv}{{\cal P}}$
# $\newcommand{\Qc}{{\cal Q}}$
# $\newcommand{\Rrv}{{\cal R}}$
# $\newcommand{\Srv}{{\cal S}}$
# $\newcommand{\Trv}{{\cal T}}$
# $\newcommand{\Urv}{{\cal U}}$
# $\newcommand{\Wrv}{{\cal W}}$
# $\newcommand{\Vrv}{{\cal V}}$
# $\newcommand{\Xrv}{{\cal X}}$
# $\newcommand{\Yrv}{{\cal Y}}$
# $\newcommand{\Zrv}{{\cal Z}}$
# $\newcommand{\Arvvec}{\mathbfcal{A}}$
# $\newcommand{\Brvvec}{\mathbfcal{B}}$
# $\newcommand{\Crvvec}{\mathbfcal{C}}$
# $\newcommand{\Drvvec}{\mathbfcal{D}}$
# $\newcommand{\Ervvec}{\mathbfcal{E}}$
# $\newcommand{\Frvvec}{\mathbfcal{F}}$
# $\newcommand{\Grvvec}{\mathbfcal{G}}$
# $\newcommand{\Hrvvec}{\mathbfcal{H}}$
# $\newcommand{\Irvvec}{\mathbfcal{I}}$
# $\newcommand{\Jrvvec}{\mathbfcal{J}}$
# $\newcommand{\Krvvec}{\mathbfcal{K}}$
# $\newcommand{\Lrvvec}{\mathbfcal{L}}$
# $\newcommand{\Mrvvec}{\mathbfcal{M}}$
# $\newcommand{\Nrvvec}{\mathbfcal{N}}$
# $\newcommand{\Orvvec}{\mathbfcal{O}}$
# $\newcommand{\Prvvec}{\mathbfcal{P}}$
# $\newcommand{\Qrvvec}{\mathbfcal{Q}}$
# $\newcommand{\Rrvvec}{\mathbfcal{R}}$
# $\newcommand{\Srvvec}{\mathbfcal{S}}$
# $\newcommand{\Trvvec}{\mathbfcal{T}}$
# $\newcommand{\Urvvec}{\mathbfcal{U}}$
# $\newcommand{\Wrvvec}{\mathbfcal{W}}$
# $\newcommand{\Vrvvec}{\mathbfcal{V}}$
# $\newcommand{\Xrvvec}{\mathbfcal{X}}$
# $\newcommand{\Yrvvec}{\mathbfcal{Y}}$
# $\newcommand{\Zrvvec}{\mathbfcal{Z}}$
# $\newcommand{\CC}{\mathbb{C}}$
# $\newcommand{\DD}{{\mathbb{D}}}$
# $\newcommand{\EE}{{\mathds{E}}}$
# $\newcommand{\MM}{\mathbb{M}}$
# $\newcommand{\NN}{\mathbb{N}}$
# $\newcommand{\RR}{\mathbb{R}}$
# $\renewcommand{\SS}{\mathbb{S}}$
# $\newcommand{\cSS}{\overline{\mathbb{S}}}$
# $\newcommand{\XX}{\mathbb{X}}$
# $\newcommand{\YY}{\mathbb{Y}}$
# $\newcommand{\ZZ}{\mathbb{Z}}$
#
# $\newcommand{\dc}{{d_{\mathrm{c}}}}$
# $\newcommand{\df}{{d_{\rm f}}}$
# $\newcommand{\dH}{{d_{\rm H}}}$
# $\newcommand{\wH}{{w_{\rm H}}}$
# $\newcommand{\GF}{{\rm GF}}$
# $\newcommand{\gc}{{g_\mathrm{c}}}$
# $\newcommand{\gd}{{g_\mathrm{d}}}$
# $\newcommand{\gr}{{g_\mathrm{R}}}$
# $\newcommand{\Gr}{{G_\mathrm{R}}}$
# $\newcommand{\gt}{{g_\mathrm{T}}}$
# $\newcommand{\Gt}{{G_\mathrm{T}}}$
# $\newcommand{\fd}{{f_{\rm d}}}$
# $\newcommand{\fN}{{f_\mathrm{N}}}$
# $\newcommand{\La}{{L_{\rm a}}}$
# $\newcommand{\Le}{{L_{\rm e}}}$
# $\newcommand{\Lc}{{L_{\rm c}}}$
# $\newcommand{\Ng}{{N_{\rm G}}}$
# $\newcommand{\Lh}{{L_{\rm h}}}$
# $\newcommand{\Lp}{{L_{\rm p}}}$
# $\newcommand{\Lt}{{L_{\rm t}}}$
# $\newcommand{\Lx}{{L_{\mathrm{X}}}}$
# $\newcommand{\Nc}{{N_{\rm c}}}$
# $\newcommand{\Np}{{N_{\rm p}}}$
# $\newcommand{\Nr}{{N_{\rm r}}}$
# $\newcommand{\Nv}{{N_{\rm v}}}$
# $\newcommand{\Eg}{{E_{\rm G}}}$
# $\newcommand{\Eb}{{E_{\rm b}}}$
# $\newcommand{\Es}{{E_{\rm s}}}$
# $\newcommand{\Pb}{{P_{\rm b}}}$
# $\newcommand{\Pe}{{P_{\rm e}}}$
# $\newcommand{\Pf}{{P_{\rm f}}}$
# $\newcommand{\Ps}{{P_{\rm s}}}$
# $\newcommand{\Pt}{{P_{\rm{t}}}}$
# $\newcommand{\Pw}{{P_{\rm w}}}$
# $\newcommand{\Pout}{{P_{\rm out}}}$
# $\newcommand{\Rc}{R_{\mathrm c}}$
# $\newcommand{\Rh}{{R_{\rm h}}}$
# $\newcommand{\Tb}{{T_{\rm b}}}$
# $\newcommand{\Tc}{{T_{\rm c}}}$
# $\newcommand{\tc}{{t_{\rm c}}}$
# $\newcommand{\Tg}{{T_{\rm G}}}$
# $\newcommand{\TMC}{{T_{\rm MC}}}$
# $\newcommand{\TOFDM}{{T_{\rm OFDM}}}$
# $\newcommand{\Ts}{{T_{\rm s}}}$
# $\newcommand{\Cout}{{C_{\rm out}}}$
# $\newcommand{\Ia}{{I_{\mathrm{a}}}}$
# $\newcommand{\Ie}{{I_{\mathrm{e}}}}$
# $\newcommand{\Ip}{{I_{\mathrm{p}}}}$
# $\newcommand{\It}{{I_{\mathrm{tot}}}}$
#
# $\newcommand{\sigmaX}{{\sigma_{\Xrv}^2}}$
# $\newcommand{\sigmaD}{{\sigma_{\Drv}^2}}$
# $\newcommand{\sigmaS}{{\sigma_{\Srv}^2}}$
# $\newcommand{\sigmaH}{{\sigma_{\Hrv}^2}}$
# $\newcommand{\sigmaN}{{\sigma_{\Nrv}^2}}$
# $\newcommand{\sigmaW}{{\sigma_{\Wrv}^2}}$
# $\newcommand{\sigmaY}{{\sigma_{\Yrv}^2}}$

# %% [markdown]
# # 3. Orthogonal Frequency Division Multiplexing (OFDM)

# %% [markdown]
# ## 3.1 Basic Principle of Multi-Carrier Transmission<a class="anchor" id="OFDMprinciple"></a>
#
# From the previous exercise we have learned that frequency selective channels lead to intersymbol interference (ISI), which deteriorates the performance significantly. The optimal Viterbi detector performs a maximum likelihood sequence detection, but its complexity grows exponentially with the channel length $\Lh$. Hence, it becomes quickly infeasible for todays signal bandwidth.
#
# <figure><a name="MultiCarrier"></a>
#     <center>
#         <img src="Figures/part3_multi_carrier.png" align=center width=500/> <br>
#         <figcaption>
#             <b>Fig.1:</b> Principle of multi-carrier transmission
#         </figcaption>
#     </center>
# </figure>
#
# A completely different approach for a robust transmission over ISI channels is OFDM. The general idea is depicted in <a href="#MultiCarrier">Fig. 1</a>. The signal bandwidth $B$ over which the channel behaves frequency selective is divided into $N$ narrowband parts. The new subcarriers occupy a bandwidth $\frac{B}{N}$ in which the channel is approximately frequency non-selective.
#
#
# ### 3.1.1 Discrete-time OFDM system model
#
# The complete discrete-time OFDM system model is given in <a href="#OFDMsystem">Fig. 2</a>. The transmitter first divides the bit stream into $N$ parallel streams. The bits in each of these streams are mapped onto data symbols taken from conventional PSK or QAM alphabets. In practical wireless communication systems, the same modulation scheme is used for all streams. Theoretically, they can be independently chosen and adapted to the individual channel conditions of a particular subcarrier. This requires appropriate channel knowledge at the transmitter which is hard to obtain in time-varying environments.
#
# The streams' data symbols are transmitted on orthogonal subcarriers to avoid intercarrier interference. This is efficiently implemented in a blockwise fashion using the inverse fast Fourier transform (IFFT). It transforms the data from the frequency domain into the time domain. In order to avoid ISI and to preserve the subcarriers' orthogonality, a guard interval has to be inserted in front of each IFFT output vector.
#
# The receiver uses the guard interval for estimating a potential carrier frequency offsets (CFO) between transmitter and receiver. Afterwards the guard interval can be removed. Next, the data back is transformed back into the frequency domain using the FFT leading to $N$ parallel data streams. They are equalized in frequency domain by a simple scalar division with the corresponding channel coefficient, i.e. since each subcarrier is assumed to be frequency non-selective. The obtained estimates of the subcarriers' data symbols can now be detected and mapped onto the corresponding bit vectors. Finally, the bit streams are multiplexed into a single stream.
#
# <figure><a name="OFDMsystem"></a>
#     <center>
#         <img src="Figures/part3_discrete_time_OFDM.png" align=center width=600/><br>
#         <figcaption>
#             <b>Fig.2:</b> Block diagram of OFDM system
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# ### 3.1.3 Optional Questions for Self Assessment
#
# * What is a frequency-selective channel?<br>
# * How does frequency-selectivity affects the time domain?<br>
# * Which approaches have we learned in the lecture to deal with frequency-selective channels?<br>
#     * What is the optimal detector? <br>
#     * How does it work? <br>
#     * Why do we need alternative solutions?<br>
# * What is the basic idea behind OFDM? <br>
#     * How does the discrete-time OFDM system look like? Explain every block!<br>
#     * Why do we need a guard interval? How does it look like?<br>
#     * How does the equalization in OFDM work?<br>
# * What are the drawbacks of OFDM?<br>

# %% [markdown]
# ## Exercise 3.1: OFDM Transmitter
#
# <div class="alert alert-block alert-info">
#
# **Tasks:**
#
# 1. Analytical part:
#     * Determine analytically the peak-to-average power ratio (PAPR) for single-carrier systems with $M$ QAM as a function of $M$.
#     * Determine analytically the PAPR at the IFFT output of an OFDM transmitter with $N$ subcarriers and $M$ QAM as a function of $N$ and $M$. How does OFDM influence the PAPR?
# 2. Implement a generic OFDM transmitter consisting of the blocks illustrated in the [OFDM system block diagram](OFDMsystem). The input is a stream of $M$ QAM symbols and can be generated as in the first two exercises. The output shall be an OFDM signal with critical sampling. The number of subcarriers $N$ shall be adjustable. In this exercise, a guard interval is not needed and will be added later. **Be aware of an appropriate power scaling of the IFFT sucht that input and output power are identical!**
# 3. Generate a signal for $M=16$ and $N=64$ with $10^4$ OFDM symbols (without guard intervals). Compute the peak-to-average power ratios (PAPRs) per OFDM symbol numerically and determine the empirical distribution by a histogram with 50 bins. Describe your observations.
# 4. Compare the maximum PAPR with the analytical solutions. Explain the difference.
# 4. Repeat the experiment with a $N=1024$ subcarriers and explain your observations.
# </div>
#
#
# <div class="alert alert-block alert-success">
#
# **Analytical part:**
#
# 1. Peak-to-average power ratios:
#     * An $M$ QAM consists of two independent $\sqrt{M}$ ASKs. Hence, the peak power is $P_{\mathrm{peak}}=\ldots$. The average power amounts to $\bar{P}=\ldots$. Hence, the PAPR becomes
#     \begin{equation}
#         \mathrm{PAPR} = \frac{P_{\mathrm{peak}}}{\bar{P}} = \cdots
#     \end{equation}
#     * For an OFDM system, the peak power at the IFFT output is obtained when all input symbols $\ldots$. With an appropriate IFFT scaling, average input and output powers are identical. Hence, the peak in time domain must have a power that is $N$ times larger than the average power of $M$ QAM symbols. The PAPR becomes
#     \begin{equation}
#        \mathrm{PAPR} = \frac{P_{\mathrm{peak}}}{\bar{P}} = \cdots
#         \xrightarrow[M \to \infty]{} \cdots \ .
#     \end{equation}
#     * For $N=64$ and $M=16$, the PAPR amounts to $\cdots  \ \hat{\approx} \ \cdots \dB$.
#     * For $N=1024$ and $M=16$, the PAPR amounts to $\cdots  \ \hat{\approx} \ \cdots \dB$.
# </div>

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

ECCpath = 'ECCpython'
if (not ECCpath==None) and (not ECCpath in sys.path):
    sys.path.append(ECCpath)

from Modulation.modulation import Modulation


class OFDM:
    def __init__(self, N=64, Ng=16):
        # definition of main OFDM parameters for IEEE 802.11a standard
        self.N       = N      # number of subcarriers (FFT size)
        self.Ng      = Ng     # length of guard interval
        self.Nofdm   = self.N + self.Ng


    def encode(self, data):
        """
        takes data and generates plain OFDM frame
        """
        # reshape data for IFFT
        ...

        return x_cp.flatten()


    def transmission(self,x,Lh,SNRdB):
        # channel impulse response and transfer function
        ...
        self.H = np.fft.fftshift(np.fft.fft(h,n=self.N))
        # convolution with channel impulse response
        y0 = ...

        # AWGN
        ...

        # received signal
        ...

        return y_frame


    def decode(self, y_frame, Nsymbols=None):
        """
        takes synchronized received frame without header and performs OFDM demodulation
        """
        # remove guard interval of data symbols
        if Nsymbols != None:
            self.Nymbols = Nsymbols
        else:
            Nsymbols = y.shape[0] // self.Nofdm

        # remove guard interval
        ...

        # transform signal into frequency domain
        ...

        # equalization
        dtilde = ...

        return dtilde.flatten()

# %%
# cardinality of QAM
M =
m = int(np.log2(M))

# OFDM parameters
N = ...   # number of subcarriers

# number of repetitions
Nsymbols = 10000
Nbins = 50

PAPR_max = np.zeros(len(N))
PAPRdB_max = np.zeros(len(N))
hist = [None]*len(N)
bin_edges = [None]*len(N)

QAM = Modulation(m=m, coding_type='gray', modulation_type='QAM')

for runN,Nfft in enumerate(N):

    PAPR = np.zeros(Nsymbols)
    P_peak_cum = 0.0
    P_avg_cum = 0.0
    P_avg_Exp = 0.0

    # number of information bits
    N_info_bits = ...
    # generate information bits
    u = ...
    # modulation
    d = ...

    # create ofdm object and encode data vector
    ...
    x = ...

    # Peak-to-Average Power Ratio
    PAPR = ...
    PAPRdB = 10 * np.log10(PAPR)
    PAPR_max[runN] = np.amax(PAPR)
    PAPRdB_max[runN] = np.amax(PAPRdB)
    hist[runN], bin_edges[runN] = np.histogram(PAPR, bins=Nbins, density=True)

print('max. PAPRs')
print(PAPR_max)
print(PAPRdB_max)
# Out:
# max. PAPRs
# [13.18609197 17.29105513]
# [11.201161   12.37821495]

# %%
fig1 = plt.figure(figsize=(6,3))
ax1 = fig1.add_subplot(111)
xAxis0 = bin_edges[0][:-1]+(bin_edges[0][1]-bin_edges[0][0])/2
xAxis1 = bin_edges[1][:-1]+(bin_edges[1][1]-bin_edges[1][0])/2
ax1.plot(xAxis0, hist[0], 'b-', label='$N=%d$' %(N[0]))
ax1.plot(xAxis0, N[0]*(1-np.exp(-xAxis0))**(N[0]-1)*np.exp(-xAxis0), 'b--', label='$N=%d$, theory' %(N[0]))
ax1.plot(xAxis1, hist[1], 'r-', label='$N=%d$' %(N[1]))
ax1.plot(xAxis1, N[1]*(1-np.exp(-xAxis1))**(N[1]-1)*np.exp(-xAxis1), 'r--', label='$N=%d$, theory' %(N[1]))
plt.xlabel('PAPR')
plt.grid()
plt.legend()
plt.title('distribution of PAPR for $M=$%d' %(M))
plt.show()

print('mean PAPRs')
print(np.sum(xAxis0*(N[0]*(1-np.exp(-xAxis0))**(N[0]-1)*np.exp(-xAxis0)))*(xAxis0[1]-xAxis0[0]))
print(np.sum(xAxis1*(N[1]*(1-np.exp(-xAxis1))**(N[1]-1)*np.exp(-xAxis1)))*(xAxis1[1]-xAxis1[0]))
# Out:
# mean PAPRs
# 4.733160706608753
# 7.507577768170794

# %% [markdown]
# ### 3.1.2. Guard Interval, Transmisssion and linear Equalizer
#
# As shown in the <a href="#GuardInterval">Fig. 3</a>, a guard interval is inserted in front of each data block in the time domain. There are two reasons why the guard interval is essential for OFDM. First, successive OFDM symbols interfer in time domain due to the frequency selective behavior of the channel. This interference can be captured by the guard interval whose length $\Tg$ has to be longer than the channel impulse response $\Lh \Ts$. If this condition is fulfilled, removing the guard interval removes ISI as well. Second, the guard interval is not just a simple gap but contains a cyclic prefix of the current OFDM symbol. This ensures that the linear convolution of channel impulse response and transmit signal becomes a cyclic convolution (when looking at the samples of the core OFDM symbol). Applying the FFT at the receiver, the cylic convolution in the time domain is transformed into a scalar multiplication in the frequency domain. This means that the data symbols on the subcarriers are simply multiplied with the corresponding coefficients of the channel transfer function (being the discrete-time Fourier transform of the channel impulse response). Mathematically, we obtain
#
# \begin{align}
#     \yv[k] &= \Hm \cdot \xv[k] + \nv[k]
#     \qquad \xrightarrow[\text{DFT}]{} \qquad
#     \yv_{\mathrm f}[k] &= \Hm_{\mathrm f} \cdot \xv_{\mathrm f}[k] + \nv_{\mathrm f}[k] = \Hm_{\mathrm f} \cdot \dv[k] + \nv_{\mathrm f}[k]
# \end{align}
#
# with $\Hm$ beeing a cyclic Toeplitz matrix. These matrices are diagonalized by the Fourier transform. Hence, $\Hm_{\mathrm f}$ is a diagonal matrix having the channel transfer function on its diagonal. For subcarrier $i$, we obtain the scalar notation $Y_i[k] = H_i \cdot d_i[k] + N_i[k]$ in the frequency domain. This subcarrier-based scalar multiplication allows the simple equalization which itself is just a scalar division.
#
# \begin{align}
#     \tilde{\dv}[k]
#         &= \Em_{\mathrm f} \cdot \yv_{\mathrm f}[k]
#          = \Hm_{\mathrm f}^{-1} \cdot \yv_{\mathrm f}[k]
#          = \dv[k] + \Hm_{\mathrm f}^{-1} \cdot \nv_{\mathrm f}[k] \\
#     \tilde{d}_i[k]
#         &= E_{{\mathrm f},i} \cdot y_{{\mathrm f},i}[k]
#          = H_i^{-1} \cdot y_{{\mathrm f},i}[k]
#          = d_i[k] + H_{{\mathrm f},i}^{-1} \cdot n_{{\mathrm f},i}[k]
# \end{align}
#
# The linear equalizer represents the least-squares (LS) solution and removes the channel influence completely (no factor remains in front of the data symbol $d_k[k]$). However, the white Gaussian noise is also multiplied with $H_i^{-1}$. For channels with deep fades, $H_i$ is small and, hence, $H_i^{-1}$ becomes very large. This leads to a noise amplification which is typical for LS estimators. Contrarily, the noise on strong subchannels is attenuated leading to high SNRs. Therefore, the performance of OFDM systems will be dominated by those subcarriers suffering from deep fades. A way out of this dilemma is the application of error control coding which is not part of this course.
#
# <figure><a name="GuardInterval"></a>
#     <center>
#         <img src="Figures/part3_CyclicPrefix_GuardInterval.png" align=center width=400/><br><br>
#         <figcaption>
#             <b>Fig.3:</b> Illustration of guard interval
#         </figcaption>
#     </center>
# </figure>

# %% [markdown]
# ## Exercise 3.2: Guard Interval, Transmission and Equalization
#
# <div class="alert alert-block alert-info">
#
# **Tasks:**
#
# 1. According to the IEEE 802.11a standard, take the implementation of Exercise 3.1 for a 4-QAM and $N=64$ subcarriers. The guard interval has a length of $\Ng=16$ samples. Extend your model by adding a cyclic prefix in front of each multi-carrier symbol. The OFDM symbol has now a length of $N+\Ng=80$ samples, the simulation shall run without oversampling.
# 2. The channel impulse response shall be modeled as a vector $\hv = \begin{bmatrix} h_0 & \ldots & h_{\Lh} \end{bmatrix}^{\mathrm{T}}$ with $\Lh=6$. Choose the coefficients and independent complex Gaussian distributed random variables with zero mean and variance $\sigma_{\Hrv_{\mu}}^2 = \frac{1}{\Lh}$. Plot the squared magnitude of the channel transfer function versus the subcarriers. Describe your observations.
# 3. Transmit a signal consisting of 100 OFDM symbols over this frequency-selective channel and add AWGN with average power $\sigmaW=0.1$. Remove the guard intervals from the received sequence and transform the multi-carrier symbols back into the frequency domain. **Take care about the FFT normalization!**
# 4. Equalize the received signal in the frequency domain. Draw scatter plots for selected subcarriers and describe your observations.
# </div>
#
# <div class="alert alert-block alert-success">
#
# **Learning objectives:**
#
# 1.  Main OFDM parameters are:
#     * $N=64$ subcarriers per OFDM symbol
#     * Nominal RF bandwidth amounts to $B=20 \MHz$ ($10 \MHz$ in equivalent baseband)
#     * Subcarrier spacing is $\Delta F = 312.5 \kHz$
#     * Duration of core symbol is $\TMC = \frac{1}{\Delta F} = 3.2 \mus$
#     * Critical sampling rate with $N=64$ samples per core symbol becomes $\Ts^{-1} = \frac{N}{\TMC} = 20 \cdot 10^6$ s$^{-1}$
#     * Guard interval has length $\Tg=0.8 \mus$ which is equivalent to $\Ng = 16$
#     * The total length of one OFDM symbol becomes $\TOFDM = 4 \mus$ which is equivalent to 80 samples
# </div>

# %%
# cardinality of QAM
M = 4
m = int(np.log2(M))

# OFDM parameters
N = 64   # number of subcarriers
Ng = 16  # length of guard interval

# number of OFDM symbols
Nsymbols = 100

# length of channel impulse response
Lh = 6

# AWGN power
SNRdB = 10



# number of information bits
N_info_bits = ...
# information bits
u = ...
# modulation
d = ...

# OFDM encoding
x = ...

# transmission over channel
y = ...

# OFDM decoding
dtilde = ...

# %%
# selected subcarriers for exercise 3.4
# choose your own selection based on the generated channel transfer function (include good and bad subcarriers)
i = np.array([8,23,35,43,50,57])

fig2 = plt.figure(figsize=(7,3))

ax2 = fig2.add_subplot(111)
ax2.plot(np.abs(ofdm.H)**2,'b-')
ax2.plot(i,np.abs(ofdm.H[i])**2,'ro', label='selected subcarriers for Ex. 3.4')
plt.xlabel('$i$')
plt.ylabel('$|H_i|^2$')
plt.title('squared magnitude of channel transfer function')
plt.grid()
plt.legend()
plt.show()

# %%
fig3 = plt.figure(figsize=(10,6))
plt.subplots_adjust(wspace=0.35)
ds = np.reshape(d,(-1,N))
dtilde = np.reshape(dtilde,(-1,N))

ax3a = fig3.add_subplot(231)
ax3a.scatter(np.real(ds[:,i[0]]), np.imag(ds[:,i[0]]),c='k')
ax3a.scatter(np.real(dtilde[:,i[0]]), np.imag(dtilde[:,i[0]]),marker='+')
ax3a.set_aspect('equal')
xmax = np.amax([np.amax(np.abs(np.real(dtilde[:,i[0]]))),np.amax(np.abs(np.imag(dtilde[:,i[0]])))])
ax3a.set_xlim(-xmax,xmax)
ax3a.set_ylim(-xmax,xmax)
ax3a.grid()

ax3b = fig3.add_subplot(232)
ax3b.scatter(np.real(ds[:,i[1]]), np.imag(ds[:,i[1]]),c='k')
ax3b.scatter(np.real(dtilde[:,i[1]]), np.imag(dtilde[:,i[1]]),marker='+')
ax3b.set_aspect('equal')
xmax = np.amax([np.amax(np.abs(np.real(dtilde[:,i[1]]))),np.amax(np.abs(np.imag(dtilde[:,i[1]])))])
ax3b.set_xlim(-xmax,xmax)
ax3b.set_ylim(-xmax,xmax)
ax3b.grid()

ax3c = fig3.add_subplot(233)
ax3c.scatter(np.real(ds[:,i[2]]), np.imag(ds[:,i[2]]),c='k', label='$d_i[k]$')
ax3c.scatter(np.real(dtilde[:,i[2]]), np.imag(dtilde[:,i[2]]),marker='+', label='$Y_i[k]$')
ax3c.set_aspect('equal')
xmax = np.amax([np.amax(np.abs(np.real(dtilde[:,i[2]]))),np.amax(np.abs(np.imag(dtilde[:,i[2]])))])
ax3c.set_xlim(-xmax,xmax)
ax3c.set_ylim(-xmax,xmax)
ax3c.grid()

ax3d = fig3.add_subplot(234)
ax3d.scatter(np.real(ds[:,i[3]]), np.imag(ds[:,i[3]]),c='k')
ax3d.scatter(np.real(dtilde[:,i[3]]), np.imag(dtilde[:,i[3]]),marker='+')
ax3d.set_aspect('equal')
xmax = np.amax([np.amax(np.abs(np.real(dtilde[:,i[3]]))),np.amax(np.abs(np.imag(dtilde[:,i[3]])))])
ax3d.set_xlim(-xmax,xmax)
ax3d.set_ylim(-xmax,xmax)
ax3d.grid()

ax3e = fig3.add_subplot(235)
ax3e.scatter(np.real(ds[:,i[4]]), np.imag(ds[:,i[4]]),c='k')
ax3e.scatter(np.real(dtilde[:,i[4]]), np.imag(dtilde[:,i[4]]),marker='+')
ax3e.set_aspect('equal')
xmax = np.amax([np.amax(np.abs(np.real(dtilde[:,i[4]]))),np.amax(np.abs(np.imag(dtilde[:,i[4]])))])
ax3e.set_xlim(-xmax,xmax)
ax3e.set_ylim(-xmax,xmax)
ax3e.grid()

ax3f = fig3.add_subplot(236)
ax3f.scatter(np.real(ds[:,i[4]]), np.imag(ds[:,i[4]]),c='k')
ax3f.scatter(np.real(dtilde[:,i[4]]), np.imag(dtilde[:,i[4]]),marker='+')
ax3f.set_aspect('equal')
xmax = np.amax([np.amax(np.abs(np.real(dtilde[:,i[5]]))),np.amax(np.abs(np.imag(dtilde[:,i[5]])))])
ax3f.set_xlim(-xmax,xmax)
ax3f.set_ylim(-xmax,xmax)
ax3f.grid()

ax3c.legend(loc='upper left', bbox_to_anchor=(1, 1.0))

# %% [markdown]
# ## Exercise 3.3: Symbol Error Probabilities
#
# <div class="alert alert-block alert-info">
#
# **Tasks:**
#
# 1. Run a Monte-Carlo simulation for the above system and SNRs in the range from 0 dB to 20 dB in 1 dB steps. For each SNR, use 100 different channel impulse responses.
# 2. Determine the average symbol error probability for each SNR and plot it.
# 3. Compare it with the results from Exercise 2.1. What do you observe?
# </div>

# %%
# SNR of AWGN
SNRdB = np.arange(0,21)

Nchannels = 100
symbol_error = np.zeros((Nchannels, len(SNRdB)))

Delta_0 = np.amin( np.abs(QAM.constellation[1:]-QAM.constellation[:-1]) )/2.0
symbol_error = np.zeros((Nchannels, SNRdB.shape[0]))

ofdm = OFDM(N, Ng)

for s, snr in enumerate(SNRdB):
    for ...


Ps_QAM = np.mean(symbol_error, axis = 0)

# %%
from scipy.special import erfc
SNR = 10**(SNRdB/10)

fig4 = plt.figure(figsize=(6,3))
ax4 = fig4.add_subplot(111)

ax4.semilogy(SNRdB, Ps_QAM, 'b-', label='$P_s$')
ax4.semilogy(SNRdB, 1 - np.sqrt(SNR/(2+SNR)), 'k--', label='analytic, 4-QAM')
ax4.semilogy(SNRdB, 0.5*erfc(np.sqrt(SNR)), 'r-', label='AWGN')
ax4.set_xlabel('$10 \\log_{10}(E_s/N_0)$')
ax4.set_xlim(SNRdB[0]-1, SNRdB[-1]+1)
ax4.set_ylim(1e-4, 1)
ax4.grid(True)
ax4.legend(loc='upper left', bbox_to_anchor=(1, 1.0))
plt.show()
